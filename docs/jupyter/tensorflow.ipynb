# %% [markdown]
# # Demonstrating Tensorflow Modin Interoperability
# ## All the examples in this section are taken/ adapted from https://www.tensorflow.org/tutorials/load_data/pandas_dataframe

# %%
import tensorflow as tf
import modin.pandas as pd

# %%
SHUFFLE_BUFFER = 500
BATCH_SIZE = 2

csv_file = tf.keras.utils.get_file('heart.csv', 'https://storage.googleapis.com/download.tensorflow.org/data/heart.csv')

df = pd.read_csv(csv_file)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
target = df.pop('target')

# %%
numeric_feature_names = ['age', 'thalach', 'trestbps',  'chol', 'oldpeak']
numeric_features = df[numeric_feature_names]
numeric_features.head()
# Out:
#    age  thalach  trestbps  chol  oldpeak
# 0   63      150       145   233      2.3
# 1   67      108       160   286      1.5
# 2   67      129       120   229      2.6
# 3   37      187       130   250      3.5
# 4   41      172       130   204      1.4

# %%
tf.convert_to_tensor(numeric_features)
# Out:
# 2023-01-03 17:28:21.206908: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <tf.Tensor: shape=(303, 5), dtype=float64, numpy=
# array([[ 63. , 150. , 145. , 233. ,   2.3],
#        [ 67. , 108. , 160. , 286. ,   1.5],
#        [ 67. , 129. , 120. , 229. ,   2.6],
#        ...,
#        [ 65. , 127. , 135. , 254. ,   2.8],
#        [ 48. , 150. , 130. , 256. ,   0. ],
#        [ 63. , 154. , 150. , 407. ,   4. ]])>

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(numeric_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qj/jybppsbd2jl75s8y2q8s2xx80000gn/T/ipykernel_5157/2210982900.py in <module>
#       1 normalizer = tf.keras.layers.Normalization(axis=-1)
# ----> 2 normalizer.adapt(numeric_features)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/preprocessing/normalization.py in adapt(self, data, batch_size, steps)
#     240           argument is not supported with array inputs.
#     241     """
# --> 242     super().adapt(data, batch_size=batch_size, steps=steps)
#     243
#     244   def update_state(self, data):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/base_preprocessing_layer.py in adapt(self, data, batch_size, steps)
#     236     if self.built:
#     237       self.reset_state()
# --> 238     data_handler = data_adapter.DataHandler(
#     239         data,
#     240         batch_size=batch_size,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1146       self._steps_per_execution = steps_per_execution
#    1147
# -> 1148     adapter_cls = select_data_adapter(x, y)
#    1149     self._adapter = adapter_cls(
#    1150         x,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py in select_data_adapter(x, y)
#     982   if not adapter_cls:
#     983     # TODO(scottzhu): This should be a less implementation-specific error.
# --> 984     raise ValueError(
#     985         "Failed to find data adapter that can handle "
#     986         "input: {}, {}".format(
#
# ValueError: Failed to find data adapter that can handle input: <class 'modin.pandas.dataframe.DataFrame'>, <class 'NoneType'>
